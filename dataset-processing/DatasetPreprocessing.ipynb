# %%
import numpy as np
import xarray as xr
from netCDF4 import Dataset
import os

def combine_netcdf_files(path, output_file, exclude=None):
    file_list = [path + "/" + filename for filename in os.listdir(path)]
    file_list.sort()
    # Open the first file to get dimensions and variables
    first_file = Dataset(file_list[0], 'r')
    dimensions = {dim: len(first_file.dimensions[dim]) for dim in first_file.dimensions}
    variables = first_file.variables
    dimensions['time'] = len(file_list)
    # Create the output NetCDF file
    with Dataset(output_file, 'w', format='NETCDF4') as output:
        # Create dimensions
        for dim_name, dim_size in dimensions.items():
            output.createDimension(dim_name, dim_size)

        output.createVariable('lat', np.float32,('lat',))
        output.createVariable('lon', np.float32,('lon',))

        output.variables['lat'][:] = variables['lat'][:]
        output.variables['lon'][:] = variables['lon'][:]
        
        # Combine data from all input files
        for var_name, var in variables.items():
            if var_name in exclude:
                continue
            print(var)
            arr = []
            for file_path in file_list:
                print(file_path)
                src = xr.open_dataset(file_path)
                arr.append(src[var_name].values)
            arr = np.array(arr)
            arr = arr.astype(np.float32)
            concatenated = np.transpose(arr, (1, 2, 0))
            print(concatenated)
            dtype = var.dtype
            print(np.sum(np.isnan(concatenated)))
            dimensions = var.dimensions
            output.createVariable(var_name, np.float32, ('lat', 'lon', 'time'))
            output.variables[var_name][:] = concatenated

# %%
combine_netcdf_files("STSData/MODIS-SST", "MODIS_combined_SST_monthly.nc", exclude = ["lat", "lon", "palette"])
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# uint8 qual_sst(lat, lon)
#     long_name: Quality Levels, Sea Surface Temperature
#     _FillValue: 255
#     missing_value: 255
# unlimited dimensions:
# current shape = (720, 1440)
# filling off
# STSData/MODIS-SST/AQUA_MODIS.20110901_20110930.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20111001_20111031.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20111101_20111130.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20111201_20111231.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20120101_20120131.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20120201_20120229.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20120301_20120331.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20120401_20120430.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20120501_20120531.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20120601_20120630.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20120701_20120731.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20120801_20120831.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20120901_20120930.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20121001_20121031.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20121101_20121130.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20121201_20121231.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20130101_20130131.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20130201_20130228.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20130301_20130331.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20130401_20130430.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20130501_20130531.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20130601_20130630.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20130701_20130731.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20130801_20130831.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20130901_20130930.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20131001_20131031.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20131101_20131130.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20131201_20131231.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20140101_20140131.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20140201_20140228.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20140301_20140331.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20140401_20140430.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20140501_20140531.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20140601_20140630.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20140701_20140731.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20140801_20140831.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20140901_20140930.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20141001_20141031.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20141101_20141130.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20141201_20141231.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20150101_20150131.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20150201_20150228.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20150301_20150331.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20150401_20150430.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20150501_20150531.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20150601_20150630.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20150701_20150731.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20150801_20150831.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20150901_20150930.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20151001_20151031.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20151101_20151130.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20151201_20151231.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20160101_20160131.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20160201_20160229.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20160301_20160331.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20160401_20160430.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20160501_20160531.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20160601_20160630.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20160701_20160731.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20160801_20160831.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20160901_20160930.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20161001_20161031.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20161101_20161130.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20161201_20161231.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20170101_20170131.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20170201_20170228.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20170301_20170331.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20170401_20170430.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20170501_20170531.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20170601_20170630.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20170701_20170731.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20170801_20170831.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20170901_20170930.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20171001_20171031.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20171101_20171130.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20171201_20171231.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20180101_20180131.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20180201_20180228.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20180301_20180331.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20180401_20180430.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20180501_20180531.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20180601_20180630.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20180701_20180731.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20180801_20180831.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20180901_20180930.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20181001_20181031.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20181101_20181130.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20181201_20181231.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20190101_20190131.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20190201_20190228.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20190301_20190331.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.
.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20200601_20200630.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20200701_20200731.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20200801_20200831.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20200901_20200930.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20201001_20201031.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20201101_20201130.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20201201_20201231.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20210101_20210131.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20210201_20210228.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20210301_20210331.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20210401_20210430.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20210501_20210531.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20210601_20210630.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20210701_20210731.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20210801_20210831.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20210901_20210930.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20211001_20211031.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20211101_20211130.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20211201_20211231.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20220101_20220131.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20220201_20220228.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20220301_20220331.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20220401_20220430.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20220501_20220531.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20220601_20220630.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20220701_20220731.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20220801_20220831.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20220901_20220930.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20221001_20221031.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20221101_20221130.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20221201_20221231.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20230101_20230131.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20230201_20230228.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20230301_20230331.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20230401_20230430.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20230501_20230531.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20230601_20230630.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20230701_20230731.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20230801_20230831.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20230901_20230930.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20231001_20231031.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20231101_20231130.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20231201_20231231.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20240101_20240131.L3m.MO.SST.x_sst.nc
# STSData/MODIS-SST/AQUA_MODIS.20240201_20240229.L3m.MO.SST.x_sst.nc
# [[[nan nan nan ... nan nan nan]
#   [nan nan nan ... nan nan nan]
#   [nan nan nan ... nan nan nan]
#   ...
#   [nan nan nan ... nan nan nan]
#   [nan nan nan ... nan nan nan]
#   [nan nan nan ... nan nan nan]]
#
#  [[nan nan nan ... nan nan nan]
#   [nan nan nan ... nan nan nan]
#   [nan nan nan ... nan nan nan]
#   ...
#   [nan nan nan ... nan nan nan]
#   [nan nan nan ... nan nan nan]
#   [nan nan nan ... nan nan nan]]
#
#  [[nan nan nan ... nan nan nan]
#   [nan nan nan ... nan nan nan]
#   [nan nan nan ... nan nan nan]
#   ...
#   [nan nan nan ... nan nan nan]
#   [nan nan nan ... nan nan nan]
#   [nan nan nan ... nan nan nan]]
#
#  ...
#
#  [[nan nan nan ... nan nan nan]
#   [nan nan nan ... nan nan nan]
#   [nan nan nan ... nan nan nan]
#   ...
#   [nan nan nan ... nan nan nan]
#   [nan nan nan ... nan nan nan]
#   [nan nan nan ... nan nan nan]]
#
#  [[nan nan nan ... nan nan nan]
#   [nan nan nan ... nan nan nan]
#   [nan nan nan ... nan nan nan]
#   ...
#   [nan nan nan ... nan nan nan]
#   [nan nan nan ... nan nan nan]
#   [nan nan nan ... nan nan nan]]
#
#  [[nan nan nan ... nan nan nan]
#   [nan nan nan ... nan nan nan]
#   [nan nan nan ... nan nan nan]
#   ...
#   [nan nan nan ... nan nan nan]
#   [nan nan nan ... nan nan nan]
#   [nan nan nan ... nan nan nan]]]
# 72390395

# %%
combine_netcdf_files("STSData/SSS", "OISSS_combined_SSS_monthly.nc", exclude = ["latitude", "longitude", "time"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\netCDF4\utils.py:39, in _find_dim(grp, dimname)
#      38 try:
# ---> 39     dim = group.dimensions[dimname]
#      40     break
#
# AttributeError: 'NoneType' object has no attribute 'dimensions'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\netCDF4\utils.py:43, in _find_dim(grp, dimname)
#      42 try:
# ---> 43     group = group.parent
#      44 except:
#
# AttributeError: 'NoneType' object has no attribute 'parent'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 combine_netcdf_files("STSData/SSS", "OISSS_combined_SSS_monthly.nc", exclude = ["latitude", "longitude", "time"])
#
# Cell In[3], line 20, in combine_netcdf_files(path, output_file, exclude)
#      17 for dim_name, dim_size in dimensions.items():
#      18     output.createDimension(dim_name, dim_size)
# ---> 20 output.createVariable('lat', np.float32,('lat',))
#      21 output.createVariable('lon', np.float32,('lon',))
#      23 output.variables['lat'][:] = variables['lat'][:]
#
# File src\\netCDF4\\_netCDF4.pyx:2954, in genexpr()
#
# File src\\netCDF4\\_netCDF4.pyx:2954, in genexpr()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\netCDF4\utils.py:45, in _find_dim(grp, dimname)
#      43             group = group.parent
#      44         except:
# ---> 45             raise ValueError("cannot find dimension %s in this group or parent groups" % dimname)
#      46 if dim is None:
#      47     raise KeyError("dimension %s not defined in group %s or any group in it's family tree" % (dimname, grp.path))
#
# ValueError: cannot find dimension lat in this group or parent groups

# %%
from ascat_averaged import ASCATAveraged

def read_data(filename):
    dataset = ASCATAveraged(filename, missing=missing)
    if not dataset.variables: sys.exit('file not found')
    return dataset

def get_uv(dataset):
    wspd = dataset.variables['windspd'][:,:]
    wdir = dataset.variables['winddir'][:,:]
    
    from bytemaps import get_uv
    u,v = get_uv(wspd,wdir)
    bad = np.where(wspd<0)
    u[bad] = -999
    v[bad] = -999
    return u, v

def create_nc(path, output_file):
    file_list = [path + "/" + filename for filename in os.listdir(path)]
    file_list.sort()
    first_file = read_data(file_list[0])
    with Dataset(output_file, 'w', format='NETCDF4') as output:
        # Create dimensions
        output.createDimension('longitude', 1440)
        output.createDimension('lat', 720)
        output.createDimension('time', 720)

        output.createVariable('lat', np.float32,('lat',))
        output.createVariable('longitude', np.float32,('longitude',))

        output.variables['lat'][:] = first_file.variables['lat']
        output.variables['longitude'][:] = first_file.variables['longitude']
        
        u_agg = []
        v_agg = []
        for file_path in file_list:
            print(file_path)
            src = read_data(file_path)
            u, v = get_uv(src)
            u_agg.append(u)
            v_agg.append(v)
        u_agg = np.array(u_agg)
        v_agg = np.array(v_agg)
        u_final = np.transpose(u_agg, (1, 2, 0))
        v_final = np.transpose(v_agg, (1, 2, 0))
        output.createVariable(var_name, np.float32, ('lat', 'longitude', 'time'))
        output.createVariable(var_name, np.float32, ('lat', 'longitude', 'time'))
        output.variables[var_name][:] = concatenated

# %%
create_nc("STSData/ASCAT-windraw", "ASCAT_combined_wind_monthly.nc")
# Out:
# STSData/ASCAT-windraw/ascat_201109_v02.1.gz
# STSData/ASCAT-windraw/ascat_201110_v02.1.gz
# STSData/ASCAT-windraw/ascat_201111_v02.1.gz
# STSData/ASCAT-windraw/ascat_201112_v02.1.gz
# STSData/ASCAT-windraw/ascat_201201_v02.1.gz
# STSData/ASCAT-windraw/ascat_201202_v02.1.gz
# STSData/ASCAT-windraw/ascat_201203_v02.1.gz
# STSData/ASCAT-windraw/ascat_201204_v02.1.gz
# STSData/ASCAT-windraw/ascat_201205_v02.1.gz
# STSData/ASCAT-windraw/ascat_201206_v02.1.gz
# STSData/ASCAT-windraw/ascat_201207_v02.1.gz
# STSData/ASCAT-windraw/ascat_201208_v02.1.gz
# STSData/ASCAT-windraw/ascat_201209_v02.1.gz
# STSData/ASCAT-windraw/ascat_201210_v02.1.gz
# STSData/ASCAT-windraw/ascat_201211_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201212_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201301_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201302_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201303_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201304_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201305_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201306_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201307_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201308_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201309_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201310_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201311_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201312_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201401_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201402_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201403_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201404_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201405_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201406_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201407_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201408_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201409_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201410_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201411_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201412_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201501_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201502_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201503_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201504_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201505_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201506_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201507_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201508_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201509_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201510_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201511_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201512_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201601_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201602_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201603_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201604_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201605_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201606_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201607_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201608_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201609_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201610_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201611_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201612_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201701_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201702_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201703_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201704_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201705_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201706_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201707_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201708_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201709_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201710_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201711_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201712_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201801_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201802_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201803_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201804_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201805_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201806_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201807_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201808_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201809_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201810_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201811_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201812_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201901_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201902_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201903_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201904_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201905_v02.1.gz
# STSData/ASCAT-windraw/ascatb_201906_v02.1.gz
# STSData/ASCAT-windraw/ascatc_201907_v02.1.gz
# STSData/ASCAT-windraw/ascatc_201908_v02.1.gz
# STSData/ASCAT-windraw/ascatc_201909_v02.1.gz
# STSData/ASCAT-windraw/ascatc_201910_v02.1.gz
# STSData/ASCAT-windraw/ascatc_201911_v02.1.gz
# STSData/ASCAT-windraw/ascatc_201912_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202001_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202002_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202003_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202004_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202005_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202006_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202007_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202008_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202009_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202010_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202011_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202012_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202101_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202102_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202103_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202104_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202105_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202106_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202107_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202108_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202109_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202110_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202111_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202112_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202201_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202202_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202203_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202204_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202205_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202206_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202207_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202208_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202209_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202210_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202211_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202212_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202301_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202302_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202303_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202304_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202305_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202306_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202307_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202308_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202309_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202310_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202311_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202312_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202401_v02.1.gz
# STSData/ASCAT-windraw/ascatc_202402_v02.1.gz
# (720, 1440, 150)
# (720, 1440, 150)
